# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('train.csv')
df
# Out:
#                         ID LCLAS_NM MLSFC_NM    POI_ID            POI_NM  \
# 0      KCLANPO22N000000001       장소      관광지    817379               운문호
# 1      KCLANPO22N000000002       장소      관광지   5497426               유마사
# 2      KCLANPO22N000000003       장소      관광지   5497607               안정사
# 3      KCLANPO22N000000004       장소      관광지   5545868               염불암
# 4      KCLANPO22N000000005       장소      관광지    332239               귀신사
# ...                    ...      ...      ...       ...               ...
# 37962  KCLANPO22N000037963       장소      관광지  21621787              새한항업
# 37963  KCLANPO22N000037964       장소      관광지  17484542       합천정원테마파크청와대
# 37964  KCLANPO22N000037965       장소      관광지  17804924            소호해변공원
# 37965  KCLANPO22N000037966       장소      관광지  20019753  렛츠런파크(2023년1월예정)
# 37966  KCLANPO22N000037967       장소      관광지  17411276             금당유원지
#
#       BHF_NM  ASSTN_NM   CL_CD         CL_NM           PNU CTPRVN_NM  \
# ...

# %%
지역 = '강원도'

# %%
df2 = df[df['CTPRVN_NM'].str.startswith(지역)]
df2 = df2.fillna('')
df2.head()
# Out:
#                      ID LCLAS_NM MLSFC_NM    POI_ID    POI_NM BHF_NM ASSTN_NM  \
# 11  KCLANPO22N000000012       장소      관광지  16944243  중앙로문화의거리
# 21  KCLANPO22N000000022       장소      관광지  21086082     대관령옛길
# 40  KCLANPO22N000000041       장소      관광지   5851799       인월사
# 41  KCLANPO22N000000042       장소      관광지   6838819      금강선원
# 43  KCLANPO22N000000044       장소      관광지   6853253       약천사
#
#      CL_CD     CL_NM                    PNU CTPRVN_NM SIGNGU_NM LEGALDONG_NM  \
# 11   60517  먹거리/패션거리  4210000000000000000.0       강원도       원주시          중앙동
# 21   60517  먹거리/패션거리  4220000000000000000.0       강원도       강릉시          성산면
# 40  180302      지역사찰  4220000000000000000.0       강원도       강릉시           저동
# 41  180302      지역사찰  4280000000000000000.0       강원도       양양군           서면
# 43  180302      지역사찰  4270000000000000000.0       강원도       홍천군          서석면
#
#    LI_NM  LNBR_NO  LEGALDONG_CD   ADSTRD_CD      RDNMADR_CD RDNMADR_NM  \
# ...

# %%
df2['도로명'] = 지역 +' '+ df2['SIGNGU_NM']+' '+ df2['LEGALDONG_NM']+' '+ df2['LI_NM']+' '+ df2['LNBR_NO']

# %%
df2[['POI_NM','LC_LO','LC_LA','도로명']]
# Out:
#          POI_NM       LC_LO      LC_LA                     도로명
# 11     중앙로문화의거리  127.950628  37.349666        강원도 원주시 중앙동  275
# 21        대관령옛길  128.785976  37.701884     강원도 강릉시 성산면 어흘리 761
# 40          인월사  128.900632  37.800983     강원도 강릉시 저동  06월 02일
# 41         금강선원  128.486023  37.914708    강원도 양양군 서면 갈천리 242-9
# 43          약천사  128.162860  37.730371    강원도 홍천군 서석면 어론리 산5-1
# ...         ...         ...        ...                     ...
# 37928  사천아기동물농장  128.862353  37.846549  강원도 강릉시 사천면 사천진리 305-3
# 37930  탕곡에코숲하우스  129.226292  37.147970   강원도 삼척시 가곡면 탕곡리 100-1
# 37939  요술쟁이열손가락  128.916976  37.768088    강원도 강릉시 포남동  1278-44
# 37941      풍선파티  128.580863  38.199578     강원도 속초시 교동  664-217
# 37944     색동저고리  127.910182  37.253881   강원도 원주시 흥업면 매지리 647-2
#
# [2658 rows x 4 columns]
